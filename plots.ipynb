# %% [markdown]
# # Initialize

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import MDS
import seaborn as sns

# %%
path = os.path.abspath('D:/Kaiserslautern/Documents/Course content/Thesis/Excel sheets')
data = os.path.join(path, 'main-table17.csv')
df = pd.read_csv(data)
df.set_index('Genus', inplace=True)

df.head()
# Out:
#                      Domain           Phylum                Class  \
# Genus
# Vagococcus         Bacteria       Firmicutes              Bacilli
# unclassified       Bacteria       Firmicutes              Bacilli
# Providencia        Bacteria   Proteobacteria  Gammaproteobacteria
# unclassified       Bacteria  Patescibacteria      Saccharimonadia
# Saccharimonadales  Bacteria  Patescibacteria      Saccharimonadia
#
#                                Order             Family       Species  \
# Genus
# Vagococcus           Lactobacillales      Vagococcaceae  unclassified
# unclassified         Lactobacillales       unclassified  unclassified
# Providencia         Enterobacterales     Morganellaceae  unclassified
# unclassified       Saccharimonadales       unclassified  unclassified
# Saccharimonadales  Saccharimonadales  Saccharimonadales  unclassified
#
#                    N.vespillo_b  N.vsps_n  N.vsps_p  N.vsps_o  ...  \
# ...

# %% [markdown]
# ## NMDS Plots

# %%
group_1 = ['N.vespillo_b', 'N.vsps_j', 'Yab_fpj_1', 'Yab_fpj_2', 'Yaj_fpb_1']
group_1_df = df[group_1]

colors = ['red', 'blue', 'green', 'orange', 'purple'] 

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data = mds.fit_transform(group_1_df.T)
plt.scatter(transformed_data[:, 0], transformed_data[:, 1])

for i, column_name in enumerate(group_1_df.T.index):
    plt.scatter(transformed_data[i, 0], transformed_data[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('Group 1 NMDS Plot')
plt.legend(loc='lower right')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
group_2 = ['N.vespillo_a', 'N.vsps_i', 'Yaa_fpi_1', 'Yaa_fpi_2', 'Yai_fpa_1', 'Yai_fpa_2', 'Yai_fpa_3', 'Yai_fpa_4']
group_2_df = df[group_2]

colors = ['black', 'purple', 'skyblue', 'darkblue', 'red', 'orange', 'gray', 'gold']

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data_2 = mds.fit_transform(group_2_df.T)
plt.scatter(transformed_data_2[:, 0], transformed_data_2[:, 1])

for i, column_name in enumerate(group_2_df.T.index):
    plt.scatter(transformed_data_2[i, 0], transformed_data_2[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('Group 2 NMDS Plot')
plt.legend(loc='lower left')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
group_3 = ['N.vespillo_d', 'N.vsps_l', 'Yal_fpd_1', 'Yal_fpd_2', 'Yal_fpd_3']
group_3_df = df[group_3]

colors = ['black', 'skyblue', 'darkblue', 'orange', 'gray']

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data_3 = mds.fit_transform(group_3_df.T)
plt.scatter(transformed_data_3[:, 0], transformed_data_3[:, 1])

for i, column_name in enumerate(group_3_df.T.index):
    plt.scatter(transformed_data_3[i, 0], transformed_data_3[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('NMDS Plot')
plt.legend(loc='upper left')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
group_4 = ['N.vespillo_q', 'N.vespillo_r', 'Yaq_fpr_1', 'Yaq_fpr_2']
group_4_df = df[group_4]

colors = ['red', 'orange', 'gray', 'gold']

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data_4 = mds.fit_transform(group_4_df.T)
plt.scatter(transformed_data_4[:, 0], transformed_data_4[:, 1])

for i, column_name in enumerate(group_4_df.T.index):
    plt.scatter(transformed_data_4[i, 0], transformed_data_4[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('NMDS Plot')
plt.legend(loc='lower left')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
group_5 = ['N.vsps_m', 'N.vsps_n', 'Yam_fpn_1', 'Yam_fpn_2', 'Yam_fpn_3', 'Yan_fpm_1', 'Yan_fpm_2', 'Yan_fpm_3']
group_5_df = df[group_5]

colors = ['black', 'white', 'skyblue', 'darkblue', 'red', 'orange', 'gray', 'gold']

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data_5 = mds.fit_transform(group_5_df.T)
plt.scatter(transformed_data_5[:, 0], transformed_data_5[:, 1])

for i, column_name in enumerate(group_5_df.T.index):
    plt.scatter(transformed_data_5[i, 0], transformed_data_5[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('NMDS Plot')
plt.legend(loc='upper right')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
group_6 = ['N.vsps_o', 'N.vsps_p', 'Yao_fpp_1', 'Yao_fpp_2', 'Yao_fpp_3']
group_6_df = df[group_6]

colors = ['darkblue', 'red', 'orange', 'gray', 'gold']

mds = MDS(n_components=2, metric=False, random_state=42)
transformed_data_6 = mds.fit_transform(group_6_df.T)
plt.scatter(transformed_data_6[:, 0], transformed_data_6[:, 1])

for i, column_name in enumerate(group_6_df.T.index):
    plt.scatter(transformed_data_6[i, 0], transformed_data_6[i, 1], color=colors[i], label=column_name)

plt.xlabel('NMDS 1')
plt.ylabel('NMDS 2')
plt.title('NMDS Plot')
plt.legend(loc='lower left')

plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %% [markdown]
# ## Heatmaps

# %%
group_1_df = df[group_1].copy()

group_1_df['mean_abundance'] = group_1_df.mean(axis=1)

top_20_species = group_1_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 1')
plt.show()

# %%
group_2_df = df[group_2].copy()

group_2_df['mean_abundance'] = group_2_df.mean(axis=1)

top_20_species = group_2_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 2')
plt.show()

# %%
group_3_df = df[group_3].copy()

group_3_df['mean_abundance'] = group_3_df.mean(axis=1)

top_20_species = group_3_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 3')
plt.show()

# %%
group_4_df = df[group_4].copy()

group_4_df['mean_abundance'] = group_4_df.mean(axis=1)

top_20_species = group_4_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 4')
plt.show()

# %%
group_5_df = df[group_5].copy()

group_5_df['mean_abundance'] = group_5_df.mean(axis=1)

top_20_species = group_5_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 5')
plt.show()

# %%
group_6_df = df[group_6].copy()

group_6_df['mean_abundance'] = group_6_df.mean(axis=1)

top_20_species = group_6_df.sort_values(by='mean_abundance', ascending=False).head(20)

top_20_species = top_20_species.drop(columns=['mean_abundance'])

# plt.figure(figsize=(12, 8))
sns.heatmap(top_20_species, cmap="YlGnBu", cbar_kws={'label': 'Abundance'})

plt.yticks(ticks=np.arange(0.5, len(top_20_species.index), 1), labels=top_20_species.index, rotation=0)

plt.title('Heatmap of Top 20 Genus for Group 6')
plt.show()

# %%
selected_columns = [col for col in df.columns if col.startswith('Ya') or ('Ya' in col and 'fp' in col)]
fed_columns = [col for col in df.columns if col.startswith('Ya') and ('Ya' in col and 'fp' in col and 'fed' in col)]
non_fed_columns = [col for col in df.columns if col.startswith('Ya') and ('Ya' in col and 'fp' in col and 'fed' not in col)]
fed_df = df[fed_columns]
non_fed_df = df[non_fed_columns]
selected_df = df[selected_columns]
selected_df
# Out:
#                       Yab_fpj_1  Yab_fpj_2  Yaj_fpb_1  Yaa_fpi_1  Yaa_fpi_2  \
# Genus
# Vagococcus                 7062         78       1785          0          0
# unclassified                 21       5637        918       8279          0
# Providencia                3317       2008         92         21         42
# unclassified                  0          0        204          0          0
# Saccharimonadales             0          0          9          0          0
# ...                         ...        ...        ...        ...        ...
# ZOR0006                       0          0          0          0          0
# Caldicellulosiruptor          0          0          0          0          0
# Pseudoalteromonas             0          0          0          0          0
# Gaiella                       0          0          0          0          0
# Curvibacter                   0          0          0          0          0
#
# ...

# %%
from sklearn.metrics import pairwise_distances
# combined_df = selected_df
combined_df = pd.concat([fed_df, non_fed_df])
combined_df = combined_df[~(combined_df == 0).all(axis=1)]
# print(combined_df)
combined_df.replace([np.inf, -np.inf], np.nan, inplace=True)
combined_df = combined_df.fillna(0)

distance_matrix = pairwise_distances(combined_df, metric="braycurtis")
np.fill_diagonal(distance_matrix, 0)
np.nan_to_num(distance_matrix, copy=False)

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
results = mds.fit_transform(distance_matrix)

plt.figure(figsize=(10, 8))

plt.scatter(results[:len(fed_df), 0], results[:len(fed_df), 1], color='red', label='Fed')
plt.scatter(results[len(non_fed_df):, 0], results[len(non_fed_df):, 1], color='blue', label='Non-Fed')

plt.legend()
plt.xlabel('PCoA1')
plt.ylabel('PCoA2')
plt.title('PCoA of Fed vs. Non-Fed')
plt.grid(True)
plt.show()
# Out:
# c:\Users\abeni\.conda\envs\beetles\Lib\site-packages\sklearn\manifold\_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
combined_df
# Out:
# Genus          Vagococcus  unclassified  Providencia  unclassified  \
# Yam_fpn_4_fed        2567          2465           55          3950
# Yam_fpn_5_fed        3501          2018          586           117
# Yam_fpn_6_fed        2022          3214           66            46
# Yan_fpm_4_fed        4901          2476            0          2086
# Yan_fpm_5_fed        3042          2735           49          4116
# Yan_fpm_6_fed        8263          4565           52           778
# Yao_fpp_4_fed        3455           703          500           188
# Yao_fpp_5_fed        3369          2558           43          2440
# Yao_fpp_6_fed        5019           913          894           543
# Yab_fpj_1            7062            21         3317             0
# Yab_fpj_2              78          5637         2008             0
# Yaj_fpb_1            1785           918           92           204
# Yaa_fpi_1               0          8279           21             0
# ...

# %%
from sklearn.metrics import pairwise_distances
# combined_df = selected_df
combined_df = pd.concat([fed_df.T, non_fed_df.T])
combined_df = combined_df[~(combined_df == 0).all(axis=1)]
# print(combined_df)
combined_df.replace([np.inf, -np.inf], np.nan, inplace=True)
combined_df = combined_df.fillna(0)

distance_matrix = pairwise_distances(combined_df, metric="braycurtis")
np.fill_diagonal(distance_matrix, 0)
np.nan_to_num(distance_matrix, copy=False)

mds = MDS(n_components=2, dissimilarity="precomputed", random_state=42)
results = mds.fit_transform(distance_matrix)

plt.figure(figsize=(10, 8))

plt.scatter(results[:len(fed_df.T), 0], results[:len(fed_df.T), 1], color='red', label='Fed')
plt.scatter(results[len(non_fed_df.T):, 0], results[len(non_fed_df.T):, 1], color='blue', label='Non-Fed')

plt.legend()
plt.xlabel('PCoA1')
plt.ylabel('PCoA2')
plt.title('PCoA of Fed vs. Non-Fed')
plt.grid(True)
plt.show()
