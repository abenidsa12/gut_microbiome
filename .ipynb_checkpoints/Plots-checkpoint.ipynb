# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.manifold import MDS

# %%
path = os.path.abspath('D:/Kaiserslautern/Documents/Course content/Thesis/Excel sheets')
data = os.path.join(path, 'main-table17.csv')
df = pd.read_csv(data)
df.head()
# Out:
#         Domain              Phylum                   Class  \
# 0  d__Bacteria       p__Firmicutes              c__Bacilli
# 1  d__Bacteria       p__Firmicutes              c__Bacilli
# 2  d__Bacteria   p__Proteobacteria  c__Gammaproteobacteria
# 3  d__Bacteria  p__Patescibacteria      c__Saccharimonadia
# 4  d__Bacteria  p__Patescibacteria      c__Saccharimonadia
#
#                   Order                Family                 Genus Species  \
# 0    o__Lactobacillales      f__Vagococcaceae         g__Vagococcus      __
# 1    o__Lactobacillales                    __                    __      __
# 2   o__Enterobacterales     f__Morganellaceae        g__Providencia      __
# 3  o__Saccharimonadales                    __                    __      __
# 4  o__Saccharimonadales  f__Saccharimonadales  g__Saccharimonadales      __
#
#    N.vespillo_b  N.vsps_n  N.vsps_p  ...  N.vespilloides_f_lab2  \
# 0          2019      2477       992  ...                   1173
# ...

# %%
group_1 = ['N.vespillo_b', 'N.vsps_j', 'Yab_fpj_1', 'Yab_fpj_2', 'Yaj_fpb_1']
group_1_df = df[group_1]
group_1_df
# Out:
#      N.vespillo_b  N.vsps_j  Yab_fpj_1  Yab_fpj_2  Yaj_fpb_1
# 0            2019       966       7062         78       1785
# 1            1136       390         21       5637        918
# 2             646      1808       3317       2008         92
# 3              83      1516          0          0        204
# 4               0       185          0          0          9
# ..            ...       ...        ...        ...        ...
# 449             0         0          0          0          0
# 450             0         0          0          0          0
# 451             0         0          0          0          0
# 452             0         0          0          0          0
# 453             0         0          0          0          0
#
# [454 rows x 5 columns]
